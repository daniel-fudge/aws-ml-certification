# %%
import boto3
from datetime import datetime
import io
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sagemaker
import sagemaker.amazon.common as smac
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import tarfile

# %%
# !pip install --upgrade pip --quiet
# !pip install mxnet --quiet
import mxnet as mx

# %% [markdown]
# #### Prepare the Data

# %%
df = pd.read_csv('ufo_fullset.csv', 
                 usecols=['shape', 'duration', 'witnesses', 'weather', 'latitude', 
                          'longitude', 'physicalEvidence', 'contact', 'researchOutcome'])
df['shape'] = df['shape'].fillna(df['shape'].value_counts().index[0])
df['physicalEvidence'] = df['physicalEvidence'].replace({'Y': 1, 'N': 0})
df['contact'] = df['contact'].replace({'Y': 1, 'N': 0})
df = pd.get_dummies(df, columns=['weather', 'shape'])
df['researchOutcome'] = df['researchOutcome'].replace({'unexplained': 0, 'explained': 1, 'probable': 2})
df.columns = [c.replace('weather_', '').replace('shape_', '').replace(' ', '_') for c in df.columns]

# %% [markdown]
# #### Split the data into train, validate and test sets

# %%
np.random.seed(0)
rand_split = np.random.rand(len(df))
train_list = rand_split < 0.8
val_list = (rand_split >= 0.8) & (rand_split < 0.9)
test_list = rand_split >= 0.9

data_train = df[train_list]
data_val = df[val_list]
data_test = df[test_list]

train_X = data_train.drop(columns='researchOutcome').values
train_y = data_train['researchOutcome'].values

val_X = data_val.drop(columns='researchOutcome').values
val_y = data_val['researchOutcome'].values

test_X = data_test.drop(columns='researchOutcome').values
test_y = data_test['researchOutcome'].values

# %% [markdown]
# #### Send data to S3 for training

# %%
bucket = 'acg-ml-certification-df'
train_file = 'ufo_sightings_train_recordIO_protobuf.data'

f = io.BytesIO()
smac.write_numpy_to_dense_tensor(f, train_X.astype('float32'), train_y.astype('float32'))
f.seek(0)

boto3.Session().resource('s3').Bucket(bucket).Object('algorithms_lab/linearlearner_train/{}'.format(train_file)).upload_fileobj(f)
training_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_train/{}'.format(bucket, train_file)
print('The Pipe mode recordIO protobuf training data: {}'.format(training_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf training data: s3://acg-ml-certification-df/algorithms_lab/linearlearner_train/ufo_sightings_train_recordIO_protobuf.data

# %%
validation_file = 'ufo_sightings_validatioin_recordIO_protobuf.data'

f = io.BytesIO()
smac.write_numpy_to_dense_tensor(f, val_X.astype('float32'), val_y.astype('float32'))
f.seek(0)

boto3.Session().resource('s3').Bucket(bucket).Object('algorithms_lab/linearlearner_validation/{}'.format(validation_file)).upload_fileobj(f)
validate_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_validation/{}'.format(bucket, validation_file)
print(f'The Pipe mode recordIO protobuf validation data: {validate_recordIO_protobuf_location}'
# Out:
# The Pipe mode recordIO protobuf validation data: s3://acg-ml-certification-df/algorithms_lab/linearlearner_validation/ufo_sightings_validatioin_recordIO_protobuf.data

# %% [markdown]
# ## Train the initial linear learner

# %%
container = sagemaker.image_uris.retrieve(boto3.Session().region_name, 'linear-learner', "1")
job_name = f'ufo-linear-learner-job-{datetime.now().strftime("%Y%m%d%H%M%S")}'
output_location = f's3://{bucket}/algorithms_lab/linearlearner_output'

role = sagemaker.get_execution_role()
sess = sagemaker.Session()

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess,
                                       input_mode='Pipe')

linear.set_hyperparameters(feature_dim=train_X.shape[1],
                           predictor_type='multiclass_classifier',
                           num_classes=3)

linear.fit(inputs={'train': training_recordIO_protobuf_location,
                   'validation': validate_recordIO_protobuf_location}, job_name=job_name)
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-05-29 16:36:21 Starting - Starting the training job...
# 2021-05-29 16:36:48 Starting - Launching requested ML instancesProfilerReport-1622306181: InProgress
# .........
# 2021-05-29 16:38:08 Starting - Preparing the instances for training......
# 2021-05-29 16:39:20 Downloading - Downloading input data...
# 2021-05-29 16:39:49 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [05/29/2021 16:40:07 INFO 139924883953472] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [05/29/2021 16:40:07 INFO 139924883953472] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '22', 'num_classes': '3', 'predictor_type': 'multiclass_classifier'}
# [05/29/2021 16:40:07 INFO 139924883953472] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '22', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '3', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'multiclass_classifier'}
# [05/29/2021 16:40:07 WARNING 139924883953472] Loggers have already been setup.
# Process 1 is a worker.
# [05/29/2021 16:40:07 INFO 139924883953472] Using default worker.
# [05/29/2021 16:40:07 INFO 139924883953472] Checkpoint loading and saving are disabled.
# [05/29/2021 16:40:07 INFO 139924883953472] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [05/29/2021 16:40:07 INFO 139924883953472] The channel 'validation' is in pipe input mode under /opt/ml/input/data/validation.
# [2021-05-29 16:40:07.616] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-05-29 16:40:08.650] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1037, "num_examples": 1, "num_bytes": 132000}
# [05/29/2021 16:40:08 INFO 139924883953472] Create Store: local
# [2021-05-29 16:40:09.781] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 1130, "num_examples": 11, "num_bytes": 1452000}
# [05/29/2021 16:40:09 INFO 139924883953472] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f426c2d53d0>
# [05/29/2021 16:40:09 INFO 139924883953472] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [28.619652    2.2057269  10.121229   38.4891      0.35787153  0.27227587
#   0.38297123  0.3165928   0.3778538   0.3589328   0.35274127  0.3191316
#   0.32874998  0.1025828   0.47422794  0.47249642  0.28657213  0.1068277
#   0.0999454   0.2243959   0.28747982  0.22868867]
# <NDArray 22 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 5.05867310e+01  4.33200026e+00  3.77569885e+01 -8.74068527e+01
#   1.50818184e-01  8.06363672e-02  1.78545475e-01  1.12999998e-01
#   1.72545478e-01  1.51909098e-01  1.45636380e-01  1.15090914e-01
#   1.23272724e-01  1.06363660e-02  3.41545522e-01  3.36454511e-01
#   9.02727321e-02  1.15454569e-02  1.00909108e-02  5.31818196e-02
#   9.09091011e-02  5.53636365e-02]
# <NDArray 22 @cpu(0)>}
# [05/29/2021 16:40:09 INFO 139924883953472] nvidia-smi: took 0.032 seconds to run.
# [05/29/2021 16:40:09 INFO 139924883953472] nvidia-smi identified 0 GPUs.
# [05/29/2021 16:40:09 INFO 139924883953472] Number of GPUs being used: 0
# #metrics {"StartTime": 1622306409.9775264, "EndTime": 1622306409.9775636, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-05-29 16:40:11.257] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 1279, "num_examples": 15, "num_bytes": 1904760}
# #metrics {"StartTime": 1622306411.2573745, "EndTime": 1622306411.2574656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5741736166817801, "count": 1, "min": 0.5741736166817801, "max": 0.5741736166817801}}}
#
# #metrics {"StartTime": 1622306411.2575705, "EndTime": 1622306411.257593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5734025966099331, "count": 1, "min": 0.5734025966099331, "max": 0.5734025966099331}}}
#
# #metrics {"StartTime": 1622306411.25765, "EndTime": 1622306411.2576673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.44915093994140626, "count": 1, "min": 0.44915093994140626, "max": 0.44915093994140626}}}
#
# #metrics {"StartTime": 1622306411.2577217, "EndTime": 1622306411.2577322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.517720474243164, "count": 1, "min": 0.517720474243164, "max": 0.517720474243164}}}
#
# #metrics {"StartTime": 1622306411.2577906, "EndTime": 1622306411.2578065, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3975624389648437, "count": 1, "min": 0.3975624389648437, "max": 0.3975624389648437}}}
#
# #metrics {"StartTime": 1622306411.2578633, "EndTime": 1622306411.2578797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5078760070800781, "count": 1, "min": 0.5078760070800781, "max": 0.5078760070800781}}}
#
# #metrics {"StartTime": 1622306411.257934, "EndTime": 1622306411.257954, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4857117396763393, "count": 1, "min": 0.4857117396763393, "max": 0.4857117396763393}}}
#
# #metrics {"StartTime": 1622306411.2580023, "EndTime": 1622306411.2580206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5221690913609096, "count": 1, "min": 0.5221690913609096, "max": 0.5221690913609096}}}
#
# #metrics {"StartTime": 1622306411.258075, "EndTime": 1622306411.2580948, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.36556963893345423, "count": 1, "min": 0.36556963893345423, "max": 0.36556963893345423}}}
#
# #metrics {"StartTime": 1622306411.2581413, "EndTime": 1622306411.2581596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.44917081778390067, "count": 1, "min": 0.44917081778390067, "max": 0.44917081778390067}}}
#
# #metrics {"StartTime": 1622306411.2582104, "EndTime": 1622306411.2582314, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7728714991978236, "count": 1, "min": 0.7728714991978236, "max": 0.7728714991978236}}}
#
# #metrics {"StartTime": 1622306411.2582989, "EndTime": 1622306411.2583141, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5695948399135045, "count": 1, "min": 0.5695948399135045, "max": 0.5695948399135045}}}
#
# #metrics {"StartTime": 1622306411.2583675, "EndTime": 1622306411.2583847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8337339303152902, "count": 1, "min": 0.8337339303152902, "max": 0.8337339303152902}}}
#
# #metrics {"StartTime": 1622306411.2584481, "EndTime": 1622306411.2584639, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.779494140625, "count": 1, "min": 0.779494140625, "max": 0.779494140625}}}
#
# #metrics {"StartTime": 1622306411.2585292, "EndTime": 1622306411.2585485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.37786178697858536, "count": 1, "min": 0.37786178697858536, "max": 0.37786178697858536}}}
#
# #metrics {"StartTime": 1622306411.2586162, "EndTime": 1622306411.2586346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8237843976702008, "count": 1, "min": 0.8237843976702008, "max": 0.8237843976702008}}}
#
# #metrics {"StartTime": 1622306411.2586932, "EndTime": 1622306411.2587094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8051334882463728, "count": 1, "min": 0.8051334882463728, "max": 0.8051334882463728}}}
#
# #metrics {"StartTime": 1622306411.258766, "EndTime": 1622306411.2587826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.0535879908970425, "count": 1, "min": 1.0535879908970425, "max": 1.0535879908970425}}}
#
# #metrics {"StartTime": 1622306411.2588344, "EndTime": 1622306411.2588508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3425297775268555, "count": 1, "min": 0.3425297775268555, "max": 0.3425297775268555}}}
#
# #metrics {"StartTime": 1622306411.2589054, "EndTime": 1622306411.258923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5870608193533761, "count": 1, "min": 0.5870608193533761, "max": 0.5870608193533761}}}
#
# #metrics {"StartTime": 1622306411.258982, "EndTime": 1622306411.259004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5023492082868304, "count": 1, "min": 0.5023492082868304, "max": 0.5023492082868304}}}
#
# #metrics {"StartTime": 1622306411.2590685, "EndTime": 1622306411.2590857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5208471559797014, "count": 1, "min": 0.5208471559797014, "max": 0.5208471559797014}}}
#
# #metrics {"StartTime": 1622306411.259145, "EndTime": 1622306411.259161, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.38089469364711215, "count": 1, "min": 0.38089469364711215, "max": 0.38089469364711215}}}
#
# #metrics {"StartTime": 1622306411.2592173, "EndTime": 1622306411.2592337, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.45330577959333146, "count": 1, "min": 0.45330577959333146, "max": 0.45330577959333146}}}
#
# #metrics {"StartTime": 1622306411.2592943, "EndTime": 1622306411.2593093, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5751228572300502, "count": 1, "min": 0.5751228572300502, "max": 0.5751228572300502}}}
#
# #metrics {"StartTime": 1622306411.2593622, "EndTime": 1622306411.2593787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.7679666791643415, "count": 1, "min": 0.7679666791643415, "max": 0.7679666791643415}}}
#
# #metrics {"StartTime": 1622306411.2594337, "EndTime": 1622306411.2594526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.47019360787527903, "count": 1, "min": 0.47019360787527903, "max": 0.47019360787527903}}}
#
# #metrics {"StartTime": 1622306411.2595067, "EndTime": 1622306411.2595158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 1.011943333217076, "count": 1, "min": 1.011943333217076, "max": 1.011943333217076}}}
#
# [05/29/2021 16:40:11 INFO 139924883953472] #quality_metric: host=algo-1, epoch=0, train multiclass_cross_entropy_objective <loss>=0.5741736166817801
# [2021-05-29 16:40:11.282] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 0, "duration": 3664, "num_examples": 1, "num_bytes": 132000}
# [2021-05-29 16:40:12.348] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 2, "duration": 1066, "num_examples": 2, "num_bytes": 234036}
# #metrics {"StartTime": 1622306412.3595014, "EndTime": 1622306412.3595994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.3497112895967728, "count": 1, "min": 0.3497112895967728, "max": 0.3497112895967728}}}
#
# #metrics {"StartTime": 1622306412.359721, "EndTime": 1622306412.3597481, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.3677522559254706, "count": 1, "min": 0.3677522559254706, "max": 0.3677522559254706}}}
#
# #metrics {"StartTime": 1622306412.3598244, "EndTime": 1622306412.359841, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.27334118803812835, "count": 1, "min": 0.27334118803812835, "max": 0.27334118803812835}}}
#
# #metrics {"StartTime": 1622306412.3599052, "EndTime": 1622306412.3599386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.26889974440280423, "count": 1, "min": 0.26889974440280423, "max": 0.26889974440280423}}}
#
# #metrics {"StartTime": 1622306412.3600025, "EndTime": 1622306412.3600185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2509679218772032, "count": 1, "min": 0.2509679218772032, "max": 0.2509679218772032}}}
#
# #metrics {"StartTime": 1622306412.3600857, "EndTime": 1622306412.3601046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.33404460117363755, "count": 1, "min": 0.33404460117363755, "max": 0.33404460117363755}}}
#
# #metrics {"StartTime": 1622306412.3601685, "EndTime": 1622306412.3601835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.3042597203219737, "count": 1, "min": 0.3042597203219737, "max": 0.3042597203219737}}}
#
# #metrics {"StartTime": 1622306412.3602421, "EndTime": 1622306412.3602564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.3330207045846112, "count": 1, "min": 0.3330207045846112, "max": 0.3330207045846112}}}
#
# #metrics {"StartTime": 1622306412.3603208, "EndTime": 1622306412.3603392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.23143303145544716, "count": 1, "min": 0.23143303145544716, "max": 0.23143303145544716}}}
#
# #metrics {"StartTime": 1622306412.3604016, "EndTime": 1622306412.3604193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.23786437437484578, "count": 1, "min": 0.23786437437484578, "max": 0.23786437437484578}}}
#
# #metrics {"StartTime": 1622306412.3604777, "EndTime": 1622306412.3604958, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.5560959559406726, "count": 1, "min": 0.5560959559406726, "max": 0.5560959559406726}}}
#
# #metrics {"StartTime": 1622306412.3605633, "EndTime": 1622306412.3605778, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.33408480933071594, "count": 1, "min": 0.33408480933071594, "max": 0.33408480933071594}}}
#
# #metrics {"StartTime": 1622306412.3606358, "EndTime": 1622306412.3606477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.5197441845510347, "count": 1, "min": 0.5197441845510347, "max": 0.5197441845510347}}}
#
# #metrics {"StartTime": 1622306412.3607001, "EndTime": 1622306412.360717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.4695725804052982, "count": 1, "min": 0.4695725804052982, "max": 0.4695725804052982}}}
#
# #metrics {"StartTime": 1622306412.3607702, "EndTime": 1622306412.360786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2723073426842084, "count": 1, "min": 0.2723073426842084, "max": 0.2723073426842084}}}
#
# #metrics {"StartTime": 1622306412.3608356, "EndTime": 1622306412.360852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.6796519736146363, "count": 1, "min": 0.6796519736146363, "max": 0.6796519736146363}}}
#
# #metrics {"StartTime": 1622306412.3609047, "EndTime": 1622306412.360921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.6527982949538212, "count": 1, "min": 0.6527982949538212, "max": 0.6527982949538212}}}
#
# #metrics {"StartTime": 1622306412.3609672, "EndTime": 1622306412.3609843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.9858190511756204, "count": 1, "min": 0.9858190511756204, "max": 0.9858190511756204}}}
#
# #metrics {"StartTime": 1622306412.361035, "EndTime": 1622306412.3610525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2264284326474813, "count": 1, "min": 0.2264284326474813, "max": 0.2264284326474813}}}
#
# #metrics {"StartTime": 1622306412.3611147, "EndTime": 1622306412.3611329, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.36292085685235126, "count": 1, "min": 0.36292085685235126, "max": 0.36292085685235126}}}
#
# #metrics {"StartTime": 1622306412.361195, "EndTime": 1622306412.361206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.3121400543746475, "count": 1, "min": 0.3121400543746475, "max": 0.3121400543746475}}}
#
# #metrics {"StartTime": 1622306412.3612769, "EndTime": 1622306412.3612876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2982620609324327, "count": 1, "min": 0.2982620609324327, "max": 0.2982620609324327}}}
#
# #metrics {"StartTime": 1622306412.3613584, "EndTime": 1622306412.3613744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.230867277211008, "count": 1, "min": 0.230867277211008, "max": 0.230867277211008}}}
#
# #metrics {"StartTime": 1622306412.3614395, "EndTime": 1622306412.3614562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.29238346829228795, "count": 1, "min": 0.29238346829228795, "max": 0.29238346829228795}}}
#
# #metrics {"StartTime": 1622306412.3622212, "EndTime": 1622306412.3622386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.3423172229437659, "count": 1, "min": 0.3423172229437659, "max": 0.3423172229437659}}}
#
# #metrics {"StartTime": 1622306412.362305, "EndTime": 1622306412.362328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.6199422234945625, "count": 1, "min": 0.6199422234945625, "max": 0.6199422234945625}}}
#
# #metrics {"StartTime": 1622306412.3623774, "EndTime": 1622306412.3623972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.24211148145302366, "count": 1, "min": 0.24211148145302366, "max": 0.24211148145302366}}}
#
# #metrics {"StartTime": 1622306412.3624606, "EndTime": 1622306412.3624816, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.9052815961757086, "count": 1, "min": 0.9052815961757086, "max": 0.9052815961757086}}}
#
# [05/29/2021 16:40:12 INFO 139924883953472] #quality_metric: host=algo-1, epoch=0, validation multiclass_cross_entropy_objective <loss>=0.3497112895967728
# [05/29/2021 16:40:12 INFO 139924883953472] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=multiclass_cross_entropy_objective, value=0.2264284326474813
# [05/29/2021 16:40:12 INFO 139924883953472] Epoch 0: Loss improved. Updating best model
# [05/29/2021 16:40:12 INFO 139924883953472] Saving model for epoch: 0
# [05/29/2021 16:40:12 INFO 139924883953472] Saved checkpoint to "/tmp/tmpe2t9ghn4/mx-mod-0000.params"
# [05/29/2021 16:40:12 INFO 139924883953472] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1622306409.9778728, "EndTime": 1622306412.380797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 26430.0, "count": 1, "min": 26430, "max": 26430}, "Total Batches Seen": {"sum": 27.0, "count": 1, "min": 27, "max": 27}, "Max Records Seen Between Resets": {"sum": 14430.0, "count": 1, "min": 14430, "max": 14430}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 14430.0, "count": 1, "min": 14430, "max": 14430}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [05/29/2021 16:40:12 INFO 139924883953472] #throughput_metric: host=algo-1, train throughput=6004.725965790295 records/second
# [2021-05-29 16:40:13.705] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 1323, "num_examples": 15, "num_bytes": 1904760}
# #metrics {"StartTime": 1622306413.705105, "EndTime": 1622306413.7051942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.26964942605154857, "count": 1, "min": 0.26964942605154857, "max": 0.26964942605154857}}}
#
# #metrics {"StartTime": 1622306413.705297, "EndTime": 1622306413.7053142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.30881466129847934, "count": 1, "min": 0.30881466129847934, "max": 0.30881466129847934}}}
#
# #metrics {"StartTime": 1622306413.7053795, "EndTime": 1622306413.7053943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.23377992248535157, "count": 1, "min": 0.23377992248535157, "max": 0.23377992248535157}}}
#
# #metrics {"StartTime": 1622306413.7054412, "EndTime": 1622306413.7054584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.21739915466308593, "count": 1, "min": 0.21739915466308593, "max": 0.21739915466308593}}}
#
# #metrics {"StartTime": 1622306413.7054987, "EndTime": 1622306413.7055151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.213674930027553, "count": 1, "min": 0.213674930027553, "max": 0.213674930027553}}}
#
# #metrics {"StartTime": 1622306413.7055655, "EndTime": 1622306413.7055798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2714455359322684, "count": 1, "min": 0.2714455359322684, "max": 0.2714455359322684}}}
#
# #metrics {"StartTime": 1622306413.7056339, "EndTime": 1622306413.7056496, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.25677112688337056, "count": 1, "min": 0.25677112688337056, "max": 0.25677112688337056}}}
#
# #metrics {"StartTime": 1622306413.7056932, "EndTime": 1622306413.7057083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.26930381774902346, "count": 1, "min": 0.26930381774902346, "max": 0.26930381774902346}}}
#
# #metrics {"StartTime": 1622306413.7057552, "EndTime": 1622306413.7057753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.20946680341448104, "count": 1, "min": 0.20946680341448104, "max": 0.20946680341448104}}}
#
# #metrics {"StartTime": 1622306413.7058232, "EndTime": 1622306413.7058377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.28247977338518415, "count": 1, "min": 0.28247977338518415, "max": 0.28247977338518415}}}
#
# #metrics {"StartTime": 1622306413.7058997, "EndTime": 1622306413.70592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.4657755628313337, "count": 1, "min": 0.4657755628313337, "max": 0.4657755628313337}}}
#
# #metrics {"StartTime": 1622306413.7059784, "EndTime": 1622306413.7059982, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2572986580984933, "count": 1, "min": 0.2572986580984933, "max": 0.2572986580984933}}}
#
# #metrics {"StartTime": 1622306413.706056, "EndTime": 1622306413.7060738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.37487903267996653, "count": 1, "min": 0.37487903267996653, "max": 0.37487903267996653}}}
#
# #metrics {"StartTime": 1622306413.7061334, "EndTime": 1622306413.7061503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3488462655203683, "count": 1, "min": 0.3488462655203683, "max": 0.3488462655203683}}}
#
# #metrics {"StartTime": 1622306413.706201, "EndTime": 1622306413.7062197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.22614852796282087, "count": 1, "min": 0.22614852796282087, "max": 0.22614852796282087}}}
#
# #metrics {"StartTime": 1622306413.7062728, "EndTime": 1622306413.7062864, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.6010234898158482, "count": 1, "min": 0.6010234898158482, "max": 0.6010234898158482}}}
#
# #metrics {"StartTime": 1622306413.7063403, "EndTime": 1622306413.7063577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5734444492885045, "count": 1, "min": 0.5734444492885045, "max": 0.5734444492885045}}}
#
# #metrics {"StartTime": 1622306413.7064033, "EndTime": 1622306413.7064235, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.935087397984096, "count": 1, "min": 0.935087397984096, "max": 0.935087397984096}}}
#
# #metrics {"StartTime": 1622306413.7064812, "EndTime": 1622306413.7065039, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.21411798640659876, "count": 1, "min": 0.21411798640659876, "max": 0.21411798640659876}}}
#
# #metrics {"StartTime": 1622306413.7065518, "EndTime": 1622306413.70657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.3950815931047712, "count": 1, "min": 0.3950815931047712, "max": 0.3950815931047712}}}
#
# #metrics {"StartTime": 1622306413.7066245, "EndTime": 1622306413.7066414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.22413839830671037, "count": 1, "min": 0.22413839830671037, "max": 0.22413839830671037}}}
#
# #metrics {"StartTime": 1622306413.706696, "EndTime": 1622306413.7067146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.31939409419468473, "count": 1, "min": 0.31939409419468473, "max": 0.31939409419468473}}}
#
# #metrics {"StartTime": 1622306413.7067666, "EndTime": 1622306413.706783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.20713156127929688, "count": 1, "min": 0.20713156127929688, "max": 0.20713156127929688}}}
#
# #metrics {"StartTime": 1622306413.706834, "EndTime": 1622306413.706851, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.23997971452985492, "count": 1, "min": 0.23997971452985492, "max": 0.23997971452985492}}}
#
# #metrics {"StartTime": 1622306413.7068977, "EndTime": 1622306413.7069142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.2641242436000279, "count": 1, "min": 0.2641242436000279, "max": 0.2641242436000279}}}
#
# #metrics {"StartTime": 1622306413.7069678, "EndTime": 1622306413.706985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.5374363250732422, "count": 1, "min": 0.5374363250732422, "max": 0.5374363250732422}}}
#
# #metrics {"StartTime": 1622306413.7070346, "EndTime": 1622306413.7070537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.20336990792410714, "count": 1, "min": 0.20336990792410714, "max": 0.20336990792410714}}}
#
# #metrics {"StartTime": 1622306413.7071044, "EndTime": 1622306413.707117, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_multiclass_cross_entropy_objective": {"sum": 0.8286661202566964, "count": 1, "min": 0.8286661202566964, "max": 0.8286661202566964}}}
#
# [05/29/2021 16:40:13 INFO 139924883953472] #quality_metric: host=algo-1, epoch=1, train multiclass_cross_entropy_objective <loss>=0.26964942605154857
# [2021-05-29 16:40:14.782] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 1053, "num_examples": 2, "num_bytes": 234036}
# #metrics {"StartTime": 1622306414.7895317, "EndTime": 1622306414.7895849, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.23368634064185437, "count": 1, "min": 0.23368634064185437, "max": 0.23368634064185437}}}
#
# #metrics {"StartTime": 1622306414.789671, "EndTime": 1622306414.7896855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2921417201903333, "count": 1, "min": 0.2921417201903333, "max": 0.2921417201903333}}}
#
# #metrics {"StartTime": 1622306414.7897437, "EndTime": 1622306414.7897615, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.23924817355823463, "count": 1, "min": 0.23924817355823463, "max": 0.23924817355823463}}}
#
# #metrics {"StartTime": 1622306414.7898204, "EndTime": 1622306414.7898376, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.22068563720565426, "count": 1, "min": 0.22068563720565426, "max": 0.22068563720565426}}}
#
# #metrics {"StartTime": 1622306414.7899055, "EndTime": 1622306414.7899258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2208069071417398, "count": 1, "min": 0.2208069071417398, "max": 0.2208069071417398}}}
#
# #metrics {"StartTime": 1622306414.7899883, "EndTime": 1622306414.790006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2522302445757544, "count": 1, "min": 0.2522302445757544, "max": 0.2522302445757544}}}
#
# #metrics {"StartTime": 1622306414.7900567, "EndTime": 1622306414.7900712, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2540757404635064, "count": 1, "min": 0.2540757404635064, "max": 0.2540757404635064}}}
#
# #metrics {"StartTime": 1622306414.7901232, "EndTime": 1622306414.790138, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2508887534617571, "count": 1, "min": 0.2508887534617571, "max": 0.2508887534617571}}}
#
# #metrics {"StartTime": 1622306414.7902021, "EndTime": 1622306414.7902195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.22433592166459568, "count": 1, "min": 0.22433592166459568, "max": 0.22433592166459568}}}
#
# #metrics {"StartTime": 1622306414.7902763, "EndTime": 1622306414.7902906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.28022252323260366, "count": 1, "min": 0.28022252323260366, "max": 0.28022252323260366}}}
#
# #metrics {"StartTime": 1622306414.7903538, "EndTime": 1622306414.7903717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.4036437850582082, "count": 1, "min": 0.4036437850582082, "max": 0.4036437850582082}}}
#
# #metrics {"StartTime": 1622306414.7904239, "EndTime": 1622306414.7904391, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.25691032086935545, "count": 1, "min": 0.25691032086935545, "max": 0.25691032086935545}}}
#
# #metrics {"StartTime": 1622306414.7905023, "EndTime": 1622306414.790517, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.3275043898494783, "count": 1, "min": 0.3275043898494783, "max": 0.3275043898494783}}}
#
# #metrics {"StartTime": 1622306414.7905762, "EndTime": 1622306414.7905939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.31823120289311463, "count": 1, "min": 0.31823120289311463, "max": 0.31823120289311463}}}
#
# #metrics {"StartTime": 1622306414.7906566, "EndTime": 1622306414.7906737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.26722731055073057, "count": 1, "min": 0.26722731055073057, "max": 0.26722731055073057}}}
#
# #metrics {"StartTime": 1622306414.7907267, "EndTime": 1622306414.7907426, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.5654419255135629, "count": 1, "min": 0.5654419255135629, "max": 0.5654419255135629}}}
#
# #metrics {"StartTime": 1622306414.7907913, "EndTime": 1622306414.7908065, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.5321719647798576, "count": 1, "min": 0.5321719647798576, "max": 0.5321719647798576}}}
#
# #metrics {"StartTime": 1622306414.7908533, "EndTime": 1622306414.790869, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.8850885295491399, "count": 1, "min": 0.8850885295491399, "max": 0.8850885295491399}}}
#
# #metrics {"StartTime": 1622306414.790917, "EndTime": 1622306414.7909312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.3182510573919117, "count": 1, "min": 0.3182510573919117, "max": 0.3182510573919117}}}
#
# #metrics {"StartTime": 1622306414.7909799, "EndTime": 1622306414.7909932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.34201058410885504, "count": 1, "min": 0.34201058410885504, "max": 0.34201058410885504}}}
#
# #metrics {"StartTime": 1622306414.791048, "EndTime": 1622306414.791065, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.22839308995280774, "count": 1, "min": 0.22839308995280774, "max": 0.22839308995280774}}}
#
# #metrics {"StartTime": 1622306414.7911904, "EndTime": 1622306414.7912095, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.4289274522294046, "count": 1, "min": 0.4289274522294046, "max": 0.4289274522294046}}}
#
# #metrics {"StartTime": 1622306414.7912774, "EndTime": 1622306414.7912953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.24347674288591017, "count": 1, "min": 0.24347674288591017, "max": 0.24347674288591017}}}
#
# #metrics {"StartTime": 1622306414.7913475, "EndTime": 1622306414.791363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2327334882173576, "count": 1, "min": 0.2327334882173576, "max": 0.2327334882173576}}}
#
# #metrics {"StartTime": 1622306414.7914126, "EndTime": 1622306414.7914279, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2654584098252212, "count": 1, "min": 0.2654584098252212, "max": 0.2654584098252212}}}
#
# #metrics {"StartTime": 1622306414.7914777, "EndTime": 1622306414.7914937, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.49636217731576954, "count": 1, "min": 0.49636217731576954, "max": 0.49636217731576954}}}
#
# #metrics {"StartTime": 1622306414.7915468, "EndTime": 1622306414.7915645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21688149974498114, "count": 1, "min": 0.21688149974498114, "max": 0.21688149974498114}}}
#
# ...
#
# [05/29/2021 16:40:35 INFO 139924883953472] #quality_metric: host=algo-1, epoch=10, train multiclass_cross_entropy_objective <loss>=0.19590416063581195
# [2021-05-29 16:40:36.317] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 32, "duration": 1052, "num_examples": 2, "num_bytes": 234036}
# #metrics {"StartTime": 1622306436.3249593, "EndTime": 1622306436.325013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 0}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2171219827358291, "count": 1, "min": 0.2171219827358291, "max": 0.2171219827358291}}}
#
# #metrics {"StartTime": 1622306436.3251033, "EndTime": 1622306436.325125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 1}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21360375177907326, "count": 1, "min": 0.21360375177907326, "max": 0.21360375177907326}}}
#
# #metrics {"StartTime": 1622306436.32518, "EndTime": 1622306436.3251956, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 2}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21261942648847293, "count": 1, "min": 0.21261942648847293, "max": 0.21261942648847293}}}
#
# #metrics {"StartTime": 1622306436.32527, "EndTime": 1622306436.3252861, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 3}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.23242837267949362, "count": 1, "min": 0.23242837267949362, "max": 0.23242837267949362}}}
#
# #metrics {"StartTime": 1622306436.3253534, "EndTime": 1622306436.3253744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 4}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21382436305872815, "count": 1, "min": 0.21382436305872815, "max": 0.21382436305872815}}}
#
# #metrics {"StartTime": 1622306436.3254335, "EndTime": 1622306436.3254535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 5}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21717790581046426, "count": 1, "min": 0.21717790581046426, "max": 0.21717790581046426}}}
#
# #metrics {"StartTime": 1622306436.3255093, "EndTime": 1622306436.3255281, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 6}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21469932078508355, "count": 1, "min": 0.21469932078508355, "max": 0.21469932078508355}}}
#
# #metrics {"StartTime": 1622306436.3255782, "EndTime": 1622306436.3255928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 7}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21219400490869994, "count": 1, "min": 0.21219400490869994, "max": 0.21219400490869994}}}
#
# #metrics {"StartTime": 1622306436.325644, "EndTime": 1622306436.325662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 8}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.22030322940350924, "count": 1, "min": 0.22030322940350924, "max": 0.22030322940350924}}}
#
# #metrics {"StartTime": 1622306436.3257284, "EndTime": 1622306436.3257434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 9}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2584293148172016, "count": 1, "min": 0.2584293148172016, "max": 0.2584293148172016}}}
#
# #metrics {"StartTime": 1622306436.3258104, "EndTime": 1622306436.3258238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 10}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21895074817465981, "count": 1, "min": 0.21895074817465981, "max": 0.21895074817465981}}}
#
# #metrics {"StartTime": 1622306436.3258893, "EndTime": 1622306436.32591, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 11}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2123551387539437, "count": 1, "min": 0.2123551387539437, "max": 0.2123551387539437}}}
#
# #metrics {"StartTime": 1622306436.3259752, "EndTime": 1622306436.3259935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 12}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.22347972544989073, "count": 1, "min": 0.22347972544989073, "max": 0.22347972544989073}}}
#
# #metrics {"StartTime": 1622306436.3260565, "EndTime": 1622306436.3260732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 13}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.27854530433443936, "count": 1, "min": 0.27854530433443936, "max": 0.27854530433443936}}}
#
# #metrics {"StartTime": 1622306436.3261278, "EndTime": 1622306436.3261437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 14}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2393157924559583, "count": 1, "min": 0.2393157924559583, "max": 0.2393157924559583}}}
#
# #metrics {"StartTime": 1622306436.326206, "EndTime": 1622306436.3262196, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 15}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.29845026127040153, "count": 1, "min": 0.29845026127040153, "max": 0.29845026127040153}}}
#
# #metrics {"StartTime": 1622306436.3262866, "EndTime": 1622306436.3263001, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 16}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2211630144027822, "count": 1, "min": 0.2211630144027822, "max": 0.2211630144027822}}}
#
# #metrics {"StartTime": 1622306436.3263535, "EndTime": 1622306436.3263755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 17}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.5303084303010875, "count": 1, "min": 0.5303084303010875, "max": 0.5303084303010875}}}
#
# #metrics {"StartTime": 1622306436.326423, "EndTime": 1622306436.3264434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 18}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2820540512609939, "count": 1, "min": 0.2820540512609939, "max": 0.2820540512609939}}}
#
# #metrics {"StartTime": 1622306436.326511, "EndTime": 1622306436.3265224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 19}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.365674254992421, "count": 1, "min": 0.365674254992421, "max": 0.365674254992421}}}
#
# #metrics {"StartTime": 1622306436.3265946, "EndTime": 1622306436.3266094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 20}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.23001052159343274, "count": 1, "min": 0.23001052159343274, "max": 0.23001052159343274}}}
#
# #metrics {"StartTime": 1622306436.3266566, "EndTime": 1622306436.32668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 21}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.5122180299710501, "count": 1, "min": 0.5122180299710501, "max": 0.5122180299710501}}}
#
# #metrics {"StartTime": 1622306436.3267407, "EndTime": 1622306436.3267615, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 22}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2143193915679639, "count": 1, "min": 0.2143193915679639, "max": 0.2143193915679639}}}
#
# #metrics {"StartTime": 1622306436.3268223, "EndTime": 1622306436.326843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 23}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.21336407777083774, "count": 1, "min": 0.21336407777083774, "max": 0.21336407777083774}}}
#
# #metrics {"StartTime": 1622306436.3268924, "EndTime": 1622306436.3269157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 24}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2124409339418535, "count": 1, "min": 0.2124409339418535, "max": 0.2124409339418535}}}
#
# #metrics {"StartTime": 1622306436.32698, "EndTime": 1622306436.32699, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 25}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.217523918001247, "count": 1, "min": 0.217523918001247, "max": 0.217523918001247}}}
#
# #metrics {"StartTime": 1622306436.327061, "EndTime": 1622306436.3270776, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 26}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.2120223370770983, "count": 1, "min": 0.2120223370770983, "max": 0.2120223370770983}}}
#
# #metrics {"StartTime": 1622306436.3271432, "EndTime": 1622306436.3271608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 27}, "Metrics": {"validation_multiclass_cross_entropy_objective": {"sum": 0.33130912113781374, "count": 1, "min": 0.33130912113781374, "max": 0.33130912113781374}}}
#
# [05/29/2021 16:40:36 INFO 139924883953472] #quality_metric: host=algo-1, epoch=10, validation multiclass_cross_entropy_objective <loss>=0.2171219827358291
# [05/29/2021 16:40:36 INFO 139924883953472] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=multiclass_cross_entropy_objective, value=0.2120223370770983
# [05/29/2021 16:40:36 INFO 139924883953472] Saving model for epoch: 10
# [05/29/2021 16:40:36 INFO 139924883953472] Saved checkpoint to "/tmp/tmpd8_o542e/mx-mod-0000.params"
# [05/29/2021 16:40:36 INFO 139924883953472] Early stop condition met. Stopping training.
# [05/29/2021 16:40:36 INFO 139924883953472] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1622306433.9654074, "EndTime": 1622306436.3349466, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 170730.0, "count": 1, "min": 170730, "max": 170730}, "Total Batches Seen": {"sum": 177.0, "count": 1, "min": 177, "max": 177}, "Max Records Seen Between Resets": {"sum": 14430.0, "count": 1, "min": 14430, "max": 14430}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 14430.0, "count": 1, "min": 14430, "max": 14430}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [05/29/2021 16:40:36 INFO 139924883953472] #throughput_metric: host=algo-1, train throughput=6089.487573477744 records/second
# [05/29/2021 16:40:36 WARNING 139924883953472] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/29/2021 16:40:36 WARNING 139924883953472] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-05-29 16:40:37.408] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 35, "duration": 1054, "num_examples": 2, "num_bytes": 234036}
# [05/29/2021 16:40:37 INFO 139924883953472] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=multiclass_cross_entropy_objective, value=0.2120223370770983
# [2021-05-29 16:40:38.454] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 37, "duration": 1033, "num_examples": 2, "num_bytes": 234036}
# [05/29/2021 16:40:38 INFO 139924883953472] #validation_score (algo-1) : ('multiclass_cross_entropy_objective', 0.21201649346865306)
# [05/29/2021 16:40:38 INFO 139924883953472] #validation_score (algo-1) : ('multiclass_accuracy', 0.9396503102086858)
# [05/29/2021 16:40:38 INFO 139924883953472] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [05/29/2021 16:40:38 INFO 139924883953472] #validation_score (algo-1) : ('dcg', 0.9758805792948921)
# [05/29/2021 16:40:38 INFO 139924883953472] #validation_score (algo-1) : ('macro_recall', 0.9271045)
# [05/29/2021 16:40:38 INFO 139924883953472] #validation_score (algo-1) : ('macro_precision', 0.8962018)
# [05/29/2021 16:40:38 INFO 139924883953472] #validation_score (algo-1) : ('macro_f_1.000', 0.9107814)
# [05/29/2021 16:40:38 INFO 139924883953472] #quality_metric: host=algo-1, validation multiclass_cross_entropy_objective <loss>=0.21201649346865306
# [05/29/2021 16:40:38 INFO 139924883953472] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.9396503102086858
# [05/29/2021 16:40:38 INFO 139924883953472] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=1.0
# [05/29/2021 16:40:38 INFO 139924883953472] #quality_metric: host=algo-1, validation dcg <score>=0.9758805792948921
# [05/29/2021 16:40:38 INFO 139924883953472] #quality_metric: host=algo-1, validation macro_recall <score>=0.9271044731140137
# [05/29/2021 16:40:38 INFO 139924883953472] #quality_metric: host=algo-1, validation macro_precision <score>=0.8962017893791199
# [05/29/2021 16:40:38 INFO 139924883953472] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.9107813835144043
# [05/29/2021 16:40:38 INFO 139924883953472] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.03578924546103785, "l1": 0.3730851993396367, "wd": 0.0020367449461466797, "lr_scheduler_step": 153, "lr_scheduler_factor": 0.9895518165671255, "lr_scheduler_minimum_lr": 2.294182951069527e-05}
# [05/29/2021 16:40:38 INFO 139924883953472] Saved checkpoint to "/tmp/tmp0hzldtw3/mx-mod-0000.params"
# [05/29/2021 16:40:38 INFO 139924883953472] Test data is not provided.
# #metrics {"StartTime": 1622306407.6123507, "EndTime": 1622306438.4869118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1351.9387245178223, "count": 1, "min": 1351.9387245178223, "max": 1351.9387245178223}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 8.517026901245117, "count": 12, "min": 0.19788742065429688, "max": 1.140594482421875}, "update.time": {"sum": 26311.219692230225, "count": 11, "min": 2361.3736629486084, "max": 2449.1357803344727}, "finalize.time": {"sum": 2140.523672103882, "count": 1, "min": 2140.523672103882, "max": 2140.523672103882}, "setuptime": {"sum": 24.558544158935547, "count": 1, "min": 24.558544158935547, "max": 24.558544158935547}, "totaltime": {"sum": 31102.74577140808, "count": 1, "min": 31102.74577140808, "max": 31102.74577140808}}}
# 2021-05-29 16:40:51 Uploading - Uploading generated training model
# 2021-05-29 16:40:51 Completed - Training job completed
# Training seconds: 91
# Billable seconds: 91

# %% [markdown]
# #### Deploy initial model and evaluate

# %%
predictor = linear.deploy(initial_instance_count=1, instance_type='ml.c4.xlarge')
predictor.serializer = sagemaker.serializers.CSVSerializer()
predictor.deserializer = sagemaker.deserializers.JSONDeserializer()
# Out:
# ---------------!

# %%
def check(x, y_true):
    y_pred = np.array([p['predicted_label'] for p in predictor.predict(x)['predictions']])
    print(f"Accuracy:  {accuracy_score(y_true, y_pred):.4f}")
    print(f"Recall:    {recall_score(y_true, y_pred, average='macro'):.4f}")
    print(f"Precision: {precision_score(y_true, y_pred, average='macro'):.4f}")
    print(f"f1:        {f1_score(y_true, y_pred, average='macro'):.4f}")

# %%
print('** Test Results **')
check(test_X, test_y)
# Out:
# ** Test Results **
# Accuracy:  0.9499
# Recall:    0.9365
# Precision: 0.9127
# f1:        0.9241

# %%
print('** Validation Results **')
check(val_X, val_y)
# Out:
# ** Validation Results **
# Accuracy:  0.9397
# Recall:    0.9271
# Precision: 0.8962
# f1:        0.9108

# %%
print('** Train Results **')
check(train_X, train_y)
# Out:
# ** Train Results **
# Accuracy:  0.9459
# Recall:    0.9296
# Precision: 0.9009
# f1:        0.9144

# %%
predictor.delete_endpoint()

# %% [markdown]
# ## Create a Hyperparameter Tuning Job
